# %% [markdown]
# # Quanvolutional Neural Networks
#
# In this example we are exploring quantum circuits with a real-world dataset, the digits recognition MNIST dataset. We will be implementing a quantum version of the Convolutional Neural Network (CNNs) in machine learning. The model is called a Quanvolutional Neural Network, a quatum machine learning model introduced in this [paper](https://arxiv.org/abs/1904.04767).
#
# We are buliding a quantum version of CNNs because their know to perform well on image dataset. Our experiment will use the MNIST dataset from Keras. The layer to which the local convolution is applied will be represented by qubits or quantum circuit wires..
#
# Let's start with theimport of the required interface and libraries, mainly PennyLae with the Tensorflow interface.

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# 2024-08-10 00:47:16.879245: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# CNNs required some parameter before training a data such as:
# - the number of optimization epochs up to it the training should be run,
# - the number of random layers contained in the neural network,
# Let's initialize them:

# %%
n_epochs = 30   # Number of optimization epochs
n_layers = 1    # Number of random layers
n_train = 50    # Size of the train dataset
n_test = 30     # Size of the test dataset

SAVE_PATH = "quanvolution/"  # Data saving folder
PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(0)           # Seed for NumPy random number generator
tf.random.set_seed(0)       # Seed for TensorFlow random number generator

# %% [markdown]
# We are set to retreive our data. The MNIST data is a very large dataset so we only be using a small part of it in this example. As with any training process, the largest dataset result in a very large training time. The previously declared variables n_train and n_test give the size of the data we will retrive from the MNIST dataset.
#
# Let's laod our data and preprocess it for our use:

# %%
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)

# %% [markdown]
# Our goal here is to create convolutional nueral network with quantum circuit. We need a device to run the circuit on and this circuit contain layers of qubits or wires.
#
# In our example, we will randomly get the circuit parameters and use 1 convoluted layer on a device of 4 qubits/wires.

# %%
dev = qml.device("default.qubit", wires=4)
# Random circuit parameters
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

@qml.qnode(dev)
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %% [markdown]
# We will apply a rotation on the Y-axis of the retrieved and scaled angles, then create a random quatum circuit and retrieve expected values afater measurement of the quatum states.
#
# We are working with images which have pixels values and a device of 4 wires. We take the imput imput and divide into squares of 2 X 2 pixels and process each sqaure. After measurment, we mapped the expectation values to a sinle pixel for the output. We are using squares of pixels as to represent each image in a matrix format.

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %% [markdown]
# We can now pre-process our data and make it ready for learning, including the convolutional layer which will nnot be trained.

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
# 50/50
# Quantum pre-processing of test images:
# 30/30

# %% [markdown]
# The data is ready and can be visualized for initial analysis before training.

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# In CNNs, an activation function is required to introduice some important techniques in the neural networks such as: non-linearity, sparisty or hierarchical learning in the layers. Gradients are used for improvement on the objective function or loss function of the model.
#
# we will use softmax for the activation function and compile our model with stochastic-gradient. The model's performance will be evaluated with cross-entropy to monitore the loss cost.

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %% [markdown]
# Now we can initialize our model and train it with the preprocessed data. The test dataset will be used to validate the model's learning after training.

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 1s - 49ms/step - accuracy: 0.0800 - loss: 2.9871 - val_accuracy: 0.1667 - val_loss: 2.3770
# Epoch 2/30
# 13/13 - 0s - 4ms/step - accuracy: 0.2600 - loss: 2.1262 - val_accuracy: 0.2000 - val_loss: 2.1507
# Epoch 3/30
# 13/13 - 0s - 4ms/step - accuracy: 0.3600 - loss: 1.8406 - val_accuracy: 0.2667 - val_loss: 1.9848
# Epoch 4/30
# 13/13 - 0s - 4ms/step - accuracy: 0.5400 - loss: 1.5049 - val_accuracy: 0.4333 - val_loss: 1.8099
# Epoch 5/30
# 13/13 - 0s - 4ms/step - accuracy: 0.7600 - loss: 1.2486 - val_accuracy: 0.5000 - val_loss: 1.6881
# Epoch 6/30
# 13/13 - 0s - 4ms/step - accuracy: 0.8800 - loss: 1.0444 - val_accuracy: 0.4667 - val_loss: 1.5931
# Epoch 7/30
# 13/13 - 0s - 4ms/step - accuracy: 0.9000 - loss: 0.8782 - val_accuracy: 0.4667 - val_loss: 1.5062
# Epoch 8/30
# 13/13 - 0s - 4ms/step - accuracy: 0.9800 - loss: 0.7437 - val_accuracy: 0.5000 - val_loss: 1.4347
# Epoch 9/30
# ...

# %% [markdown]
# The above training was performed with a hybrid quantum classical model with pre-processed data. We can observe the loss function's decrease at epoch both on thet training and validation set.
#
# We need to evaluate this performance and compare results. We use classical instance of our model with the non-preprocessed data to see how well the model learns.

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 1s - 53ms/step - accuracy: 0.1000 - loss: 2.2599 - val_accuracy: 0.2333 - val_loss: 2.2346
# Epoch 2/30
# 13/13 - 0s - 6ms/step - accuracy: 0.5400 - loss: 1.8545 - val_accuracy: 0.3000 - val_loss: 2.0952
# Epoch 3/30
# 13/13 - 0s - 5ms/step - accuracy: 0.7200 - loss: 1.5753 - val_accuracy: 0.4333 - val_loss: 1.9681
# Epoch 4/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9000 - loss: 1.3486 - val_accuracy: 0.4667 - val_loss: 1.8494
# Epoch 5/30
# 13/13 - 0s - 5ms/step - accuracy: 0.9000 - loss: 1.1597 - val_accuracy: 0.5000 - val_loss: 1.7443
# Epoch 6/30
# 13/13 - 0s - 5ms/step - accuracy: 0.9600 - loss: 1.0030 - val_accuracy: 0.5000 - val_loss: 1.6556
# Epoch 7/30
# 13/13 - 0s - 5ms/step - accuracy: 0.9600 - loss: 0.8735 - val_accuracy: 0.5000 - val_loss: 1.5821
# Epoch 8/30
# 13/13 - 0s - 4ms/step - accuracy: 0.9800 - loss: 0.7662 - val_accuracy: 0.5667 - val_loss: 1.5213
# Epoch 9/30
# ...

# %% [markdown]
# Comparing the result from the classical instance to the instance with the quantum computation, we can conclude that the model has a goo dperformance.
#
# Let's visualize the training results with and without quatum convolutional layer:

# %%
import matplotlib.pyplot as plt
import seaborn

plt.style.use("seaborn-v0_8")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Resources
# - Source: https://arxiv.org/abs/1904.04767
# - https://arxiv.org/abs/1904.04767
